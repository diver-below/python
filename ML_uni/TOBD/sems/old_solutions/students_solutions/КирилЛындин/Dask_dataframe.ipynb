# %%
import os
import dask
import dask.dataframe as dd
import dask.bag as db
import json
from collections import Counter

# %%
filenames = os.path.join(r'C:\Users\miair\Documents\Python\Лекции big data\archive\data', 'accounts.*.csv')

# %%
df = dd.read_csv(filenames, 
                    dtype = {'id' : int,
                            'names' : str,
                            'amount' : int})

# %%
df.head()
# Out:
#     id    names  amount
# 0  477    Alice      44
# 1  486    Alice     385
# 2  172   Yvonne    3711
# 3  365  Charlie    1880
# 4  196   Yvonne     423

# %%
df.dtypes
# Out:
# id         int32
# names     object
# amount     int32
# dtype: object

# %% [markdown]
# Задача 1: вывести самое часто встречающееся имя

# %%
df2 = df.where(df.amount > 0).groupby('names').id.count().idxmax()

# %%
df2.compute()
# Out:
# 'Charlie'

# %% [markdown]
# Задача 2 сделать новую колонку, которая является результатом от деления нацело на 100, если amount > 100 и нулём, если меньше

# %%
df4 = df
df4 = df4.assign(new = lambda df: df.amount// 100)
df4.new = df4.new.where(df4.new > 0 , 0)

# %%
df4.compute()
# Out:
#          id     names  amount  new
# 0       477     Alice      44    0
# 1       486     Alice     385    3
# 2       172    Yvonne    3711   37
# 3       365   Charlie    1880   18
# 4       196    Yvonne     423    4
# 5       230     Zelda    4360   43
# 6        22     Edith    1897   18
# 7       197     Quinn    1529   15
# 8       467    Xavier      85    0
# 9         9    Victor     999    9
# 10      196    Yvonne     362    3
# 11      154   Michael    1609   16
# 12      391   Norbert    2155   21
# 13       27       Tim     -58    0
# 14        4     Kevin    1042   10
# 15      499     Sarah    1426   14
# 16      366  Patricia    -236    0
# 17      440    Hannah     811    8
# 18      154   Michael    1426   14
# 19      261    Victor    -216    0
# 20       88    Victor     324    3
# 21      147     Sarah     543    5
# 22      277    Oliver    1028   10
# 23      489     Quinn      49    0
# 24      280       Ray    2059   20
# 25      256     Wendy    1137   11
# 26      409     Edith    1744   17
# 27       47    Hannah     160    1
# 28      214   Norbert    -629    0
# 29       12   Charlie    2324   23
# ...     ...       ...     ...  ...
# 999970  113    Ingrid      21    0
# 999971  224    Yvonne     107    1
# 999972  465    Yvonne   -3765    0
# 999973   12   Charlie    2042   20
# 999974  426    George     125    1
# 999975  348    Ursula      90    0
# 999976   47    Hannah     172    1
# 999977    5    Hannah     607    6
# 999978  166     Kevin     584    5
# 999979  458     Jerry    4395   43
# 999980  216     Wendy     126    1
# 999981  366  Patricia    -127    0
# 999982   94     Frank      86    0
# 999983  465    Yvonne   -3606    0
# 999984   19       Dan    6434   64
# 999985  158    Yvonne     -90    0
# 999986  167  Patricia      66    0
# 999987   34   Michael     164    1
# 999988   92     Wendy     -86    0
# 999989  404     Kevin    1392   13
# 999990  278   Charlie    -602    0
# 999991  328   Norbert    3762   37
# 999992    5    Hannah     844    8
# 999993  171   Charlie     476    4
# 999994   26       Bob     261    2
# 999995  198    Hannah    -532    0
# 999996  461    George     363    3
# 999997  135  Patricia    1548   15
# 999998  453   Charlie      84    0
# 999999  216     Wendy     161    1
#
# [6000000 rows x 4 columns]

# %% [markdown]
# Эффективно создать csv файлы, содержащие данные из файлов `accounts.*.csv` к которым добавлен столбец, в котором содержится количество сотен из положительного значения amount и 0, если значение в amount отрицательное.

# %%
df4.to_csv('accounts_new.*.csv')
# Out:
# ['accounts_new.0.csv',
#  'accounts_new.1.csv',
#  'accounts_new.2.csv',
#  'accounts_new.3.csv',
#  'accounts_new.4.csv',
#  'accounts_new.5.csv']

# %% [markdown]
# Задача 3: посчитать 10 децилей колонки amount

# %%
# %%time
dist = df.amount.quantile([0.1 * x for x in range(1,10)]).compute()
print(dist)
# Out:
# 0.1    -156.0
# 0.2      34.0
# 0.3     141.0
# 0.4     287.0
# 0.5     495.0
# 0.6     826.0
# 0.7    1191.0
# 0.8    1731.0
# 0.9    2481.0
# Name: amount, dtype: float64
# Wall time: 2.71 s

# %% [markdown]
# Задача 4: найти пару идущих подряд чисел с наибольшей по модулю разностью. При этом важно применить rolling для перехода через партиции

# %%
df.head()
# Out:
#     id    names  amount
# 0  477    Alice      44
# 1  486    Alice     385
# 2  172   Yvonne    3711
# 3  365  Charlie    1880
# 4  196   Yvonne     423

# %%
# %%time
mod = df.amount.map_overlap(lambda s: s.rolling(2).apply(lambda x: abs(x[0] - x[1])), 1, 0).idxmax().compute()
print(mod)
# Out:
# 580971
# Wall time: 9.83 s

# %% [markdown]
# Задача 5: загрузить файл в даск датафрейм и посчитать кол-во отзывов по оценкам

# %%
dfjson = dd.read_json('datasets/Toys_and_Games_5.json',
            dtype = {'asin' : str,
                            'helpful' : str,
                            'overall' : int,
                            'reviewText' : str,
                            'reviewTine' : 'datetime',
                            'reviewerID' : str,
                            'rewiewerName' : str,
                            'summary' : str,
                            'unixReviewTime' : str})
dfjson.head()
# Out:
#          asin helpful  overall  \
# 0  0439893577  [0, 0]        5
# 1  0439893577  [1, 1]        4
# 2  0439893577  [1, 1]        5
# 3  0439893577  [0, 0]        5
# 4  0439893577  [1, 1]        4
#
#                                           reviewText   reviewTime  \
# 0  I like the item pricing. My granddaughter want...  01 29, 2014
# 1  Love the magnet easel... great for moving to d...  03 28, 2014
# 2  Both sides are magnetic.  A real plus when you...  01 28, 2013
# 3  Bought one a few years ago for my daughter and...   02 8, 2014
# 4  I have a stainless steel refrigerator therefor...   05 5, 2014
#
#        reviewerID    reviewerName  \
# 0  A1VXOAVRGKGEAK           Angie
# 1   A8R62G708TSCM         Candace
# 2  A21KH420DK0ICA  capemaychristy
# 3   AR29QK6HPFYZ4            dcrm
# 4   ACCH8EOML6FN5            DoyZ
#
#                                              summary unixReviewTime
# 0                                     Magnetic board     1390953600
# 1  it works pretty good for moving to different a...     1395964800
# 2                                         love this!     1359331200
# 3                                  Daughters love it     1391817600
# 4  Great to have so he can play with his alphabet...     1399248000

# %%
dfjson.dtypes
# Out:
# asin              object
# helpful           object
# overall            int32
# reviewText        object
# reviewTime        object
# reviewerID        object
# reviewerName      object
# summary           object
# unixReviewTime    object
# dtype: object

# %%
dfjson.groupby('overall').count()
# Out:
# Dask DataFrame Structure:
#                 asin helpful reviewText reviewTime reviewerID reviewerName summary unixReviewTime
# npartitions=1
#                int64   int64      int64      int64      int64        int64   int64          int64
#                  ...     ...        ...        ...        ...          ...     ...            ...
# Dask Name: dataframe-groupby-count-agg, 9 tasks

# %%
# %%time
grouped = dfjson.groupby('overall').summary.count().compute()
print(grouped)
# Out:
# overall
# 1      4707
# 2      6298
# 3     16357
# 4     37445
# 5    102790
# Name: summary, dtype: int64
# Wall time: 9.13 s

# %% [markdown]
# Задача 6: посчиать кол-во отзывов по месяцам

# %%
Counter(dfjson[dfjson.reviewText.notnull()].reviewTime.str.slice(0, 2).compute())
# Out:
# Counter({'01': 27533,
#          '02': 13925,
#          '03': 12135,
#          '04': 10795,
#          '05': 10530,
#          '06': 10187,
#          '07': 10650,
#          '08': 9150,
#          '09': 9505,
#          '10': 11249,
#          '11': 13942,
#          '12': 27996})

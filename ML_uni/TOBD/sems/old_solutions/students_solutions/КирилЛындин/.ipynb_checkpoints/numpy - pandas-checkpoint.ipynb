# %%
import numpy as np
import pandas as pd

# %%
#Задание 1
a = np.array(list([np.random.randint(-5,6) for i in range(15)] for j in range(5)))
print(a)
b = np.array(list([np.random.randint(-5,6) for i in range(15)] for j in range(5)))
print (b)
# Out:
# [[-1 -1  5  5 -5  3  0  5 -5  4  4 -2 -3  1 -1]
#  [-5 -2  4  1 -3 -4  1  2 -2  1  1  5 -3 -2  0]
#  [ 0  4 -5  4  1  0 -3 -1  3 -3  3  1 -2 -1 -5]
#  [-5  2  3  0  2  5  1  2 -1  3  1  1 -3  3 -1]
#  [ 0 -2 -3  4  2 -2 -1 -3  3 -2 -4  5  4  2  1]]
# [[ 1 -5  5  2  3  5 -5 -4  0 -3  0  1  1  3 -5]
#  [-4  1  0  4 -2 -4 -4  3  0  3  3  0  3  1  3]
#  [ 4  5  0 -2  0  4  4 -1  3 -4  4 -3  5 -3 -3]
#  [-4 -1 -1  2  0  1  4 -1 -4  1 -1 -5  3  2 -4]
#  [ 0  5 -4 -4 -4 -3 -1 -2  5 -1 -1  4 -5  1 -1]]

# %%
#Ответ
np.where(a * b > 0, a+b , a)
# Out:
# array([[-1, -6, 10,  7, -5,  8,  0,  5, -5,  4,  4, -2, -3,  4, -6],
#        [-9, -2,  4,  5, -5, -8,  1,  5, -2,  4,  4,  5, -3, -2,  0],
#        [ 0,  9, -5,  4,  1,  0, -3, -2,  6, -7,  7,  1, -2, -4, -8],
#        [-9,  2,  3,  0,  2,  6,  5,  2, -5,  4,  1,  1, -3,  5, -5],
#        [ 0, -2, -7,  4,  2, -5, -2, -5,  8, -3, -5,  9,  4,  3,  1]])

# %%
#Задание 2
A = np.array([[8,4,15,6,9],
             [3,16,13,8,10],
             [0,9,18,17,5],
             [16,2,6,0,10],
             [18,13,9,17,8]])
A
# Out:
# array([[ 8,  4, 15,  6,  9],
#        [ 3, 16, 13,  8, 10],
#        [ 0,  9, 18, 17,  5],
#        [16,  2,  6,  0, 10],
#        [18, 13,  9, 17,  8]])

# %%
#Ответ
B = np.fromfunction(lambda i,j : A.min(axis = 1)[i] + A.min(axis = 0)[j], (5,5), dtype = 'int')
B
# Out:
# array([[ 4,  6, 10,  4,  9],
#        [ 3,  5,  9,  3,  8],
#        [ 0,  2,  6,  0,  5],
#        [ 0,  2,  6,  0,  5],
#        [ 8, 10, 14,  8, 13]])

# %%
#Задание 3
data = pd.read_csv(r"datasets/sp500hst.txt", names = ["Date", "Ticker", "Open", "High", "Low", "Close", "Volume"])
data["Date"] = pd.to_datetime(data["Date"], format = "%Y%m%d")
data.head()
# Out:
#         Date Ticker   Open     High     Low  Close  Volume
# 0 2009-08-21      A  25.60  25.6100  25.220  25.55   34758
# 1 2009-08-24      A  25.64  25.7400  25.330  25.50   22247
# 2 2009-08-25      A  25.50  25.7000  25.225  25.34   30891
# 3 2009-08-26      A  25.32  25.6425  25.145  25.48   33334
# 4 2009-08-27      A  25.50  25.5700  25.230  25.54   70176

# %%
itt = iter(data.iterrows())

# %%
data.stack()
# Out:
# 0       Date      2009-08-21 00:00:00
#         Ticker                      A
#         Open                     25.6
#         High                    25.61
#         Low                     25.22
#         Close                   25.55
#         Volume                  34758
# 1       Date      2009-08-24 00:00:00
#         Ticker                      A
#         Open                    25.64
#         High                    25.74
#         Low                     25.33
#         Close                    25.5
#         Volume                  22247
# 2       Date      2009-08-25 00:00:00
#         Ticker                      A
#         Open                     25.5
#         High                     25.7
#         Low                    25.225
#         Close                   25.34
#         Volume                  30891
# 3       Date      2009-08-26 00:00:00
#         Ticker                      A
#         Open                    25.32
#         High                  25.6425
# ...

# %%
vals = [next(itt)[1], next(itt)[1]]
vals
# Out:
# [Date      2009-09-15 00:00:00
#  Ticker                      A
#  Open                    28.01
#  High                    28.38
#  Low                     27.65
#  Close                   28.32
#  Volume                  33180
#  Name: 15, dtype: object, Date      2009-09-16 00:00:00
#  Ticker                      A
#  Open                    28.33
#  High                    28.77
#  Low                     28.33
#  Close                   28.63
#  Volume                  32339
#  Name: 16, dtype: object]

# %%
vals[0]["Date"]
# Out:
# Timestamp('2009-09-15 00:00:00')

# %%
pd.DataFrame(columns=data.columns)
# Out:
# Empty DataFrame
# Columns: [Date, Ticker, Open, High, Low, Close, Volume]
# Index: []

# %%
data.append(next(itt)[1])
# Out:
#              Date Ticker   Open     High      Low  Close  Volume
# 0      2009-08-21      A  25.60  25.6100  25.2200  25.55   34758
# 1      2009-08-24      A  25.64  25.7400  25.3300  25.50   22247
# 2      2009-08-25      A  25.50  25.7000  25.2250  25.34   30891
# 3      2009-08-26      A  25.32  25.6425  25.1450  25.48   33334
# 4      2009-08-27      A  25.50  25.5700  25.2300  25.54   70176
# 5      2009-08-28      A  25.67  26.0500  25.6300  25.83   39694
# 6      2009-08-31      A  25.45  25.7400  25.3100  25.68   51064
# 7      2009-09-01      A  25.51  26.3300  25.4800  25.85   66422
# 8      2009-09-02      A  25.97  25.9700  24.9600  25.22   64614
# 9      2009-09-03      A  25.47  25.5400  25.0000  25.29   46369
# 10     2009-09-04      A  25.37  25.9200  25.1475  25.86   32556
# 11     2009-09-09      A  26.31  27.1900  26.1600  27.15   36764
# 12     2009-09-10      A  27.08  27.8800  26.9400  27.86   42987
# ...

# %%
data['Diff'] = data['High'] - data["Low"]

# %%
data.head()
# Out:
#         Date Ticker   Open     High     Low  Close  Volume    Diff
# 0 2009-08-21      A  25.60  25.6100  25.220  25.55   34758  0.3900
# 1 2009-08-24      A  25.64  25.7400  25.330  25.50   22247  0.4100
# 2 2009-08-25      A  25.50  25.7000  25.225  25.34   30891  0.4750
# 3 2009-08-26      A  25.32  25.6425  25.145  25.48   33334  0.4975
# 4 2009-08-27      A  25.50  25.5700  25.230  25.54   70176  0.3400

# %%
data_cut = data[data.Date >= "2010-04-01"]
data_cut = data_cut[data_cut.Date < "2010-05-01"]
data_cut.head()
# Out:
#           Date Ticker   Open    High      Low  Close  Volume    Diff
# 147 2010-04-01      A  34.54  34.870  34.2500  34.55   22210  0.6200
# 148 2010-04-05      A  34.59  34.840  34.5400  34.82   26694  0.3000
# 149 2010-04-06      A  34.64  34.690  34.4200  34.56   25028  0.2700
# 150 2010-04-07      A  34.50  34.553  34.1300  34.29   23386  0.4230
# 151 2010-04-08      A  34.10  34.150  33.5494  33.99   30041  0.6006

# %%
max_dif = data_cut["Diff"].max()
max_dif
# Out:
# 79.539999999999992

# %%
#Ответ
data_cut[data_cut.Diff == max_dif]
# Out:
#             Date Ticker    Open    High    Low   Close  Volume   Diff
# 72283 2010-04-23    MIL  106.17  106.27  26.73  106.22    7019  79.54

# %%
#Задание 4
# %%file calc_.py
import numpy as np
def calc():
    res = []
    for x in range(3001):
        for y in range(x, 3001):
    return res

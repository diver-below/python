# %%
import pandas as pd
import numpy as np
import operator

# %%
import os
import dask
import dask.dataframe as dd

# %%
from prep import accounts_csvs
# генерация искуственного набора данных:
accounts_csvs(24, 1000000, 500)

# %%
filename = os.path.join('data', 'accounts.*.csv')
filename
# Out:
# 'data\\accounts.*.csv'

# %%
filename2 = os.path.join('data2', 'accounts.*.csv')
filename2
# Out:
# 'data2\\accounts.*.csv'

# %%
# Чтение всех файлов CSV, соответствующих шаблону, в Dask DataFrame:
df = dd.read_csv(filename)

# %%
df.head()
# Out:
#     id     names  amount
# 0  438     Quinn    -137
# 1  310  Patricia    1327
# 2  146    Ingrid    1825
# 3  270    Oliver    -251
# 4  355   Charlie      11

# %% [markdown]
# 1) В `accounts.*.csv` найти имя, для которого встречается наибольшее количество положительных значений в столбце amount.

# %%
# %%time
res = df[df.amount > 0].groupby('names').amount.count().idxmax().compute()
# Out:
# Wall time: 7.54 s

# %%
res
# Out:
# 'Jerry'

# %% [markdown]
# 1) В `accounts.*.csv` найти имя, для которого встречается наибольшее количество положительных значений в столбце amount.

# %%
# Чтение всех файлов CSV, соответствующих шаблону, в Dask DataFrame:
df = dd.read_csv(filename)

# %%
# %%time
df[df.amount>0].groupby('names').amount.count().idxmax().compute()
# Out:
# Wall time: 8.03 s
# 'Jerry'

# %% [markdown]
# 2) Эффективно создать csv файлы, содержащие данные из файлов `accounts.*.csv` к которым добавлен столбец, в котором содержится количество сотен из положительного значения amount и 0, если значение в amount отрицательное.
#
# Пример:
#
# `id,names,amount,new
# 412,Norbert,1492,14
# 498,Bob,-91,0
# 448,Ray,72,0`

# %%
df['new'] = df['amount'] // 100

# %%
df['new'] = df['new'].where(df['new'] > 0, 0)

# %%
df.head()
# Out:
#     id     names  amount  new
# 0  438     Quinn    -137    0
# 1  310  Patricia    1327   13
# 2  146    Ingrid    1825   18
# 3  270    Oliver    -251    0
# 4  355   Charlie      11    0

# %%
os.mkdir('data_new')

# %%
to = os.path.join("data_new", "accounts_new.*.csv")

# %%
to
# Out:
# 'data_new\\accounts_new.*.csv'

# %%
df.to_csv(to)
# Out:
# ['data_new\\accounts_new.00.csv',
#  'data_new\\accounts_new.01.csv',
#  'data_new\\accounts_new.02.csv',
#  'data_new\\accounts_new.03.csv',
#  'data_new\\accounts_new.04.csv',
#  'data_new\\accounts_new.05.csv',
#  'data_new\\accounts_new.06.csv',
#  'data_new\\accounts_new.07.csv',
#  'data_new\\accounts_new.08.csv',
#  'data_new\\accounts_new.09.csv',
#  'data_new\\accounts_new.10.csv',
#  'data_new\\accounts_new.11.csv',
#  'data_new\\accounts_new.12.csv',
#  'data_new\\accounts_new.13.csv',
#  'data_new\\accounts_new.14.csv',
#  'data_new\\accounts_new.15.csv',
#  'data_new\\accounts_new.16.csv',
#  'data_new\\accounts_new.17.csv',
#  'data_new\\accounts_new.18.csv',
#  'data_new\\accounts_new.19.csv',
#  'data_new\\accounts_new.20.csv',
#  'data_new\\accounts_new.21.csv',
#  'data_new\\accounts_new.22.csv',
#  'data_new\\accounts_new.23.csv']

# %%
df2 = dd.read_csv(filename)

# %%
df3 = df2.assign(new = df2.amount // 100)

# %%
# df3.head(15)

# %%
df3['new'] = df3['new'].where(df3['new'] > 0, 0)

# %%
# df3.head(15)

# %%
df3.to_csv(filename2).comute()

# %% [markdown]
# 3) Эффективно найти все 10 децилей для распределения значения amount.

# %%
import dask.array as da

# %%
da.percentile(df['amount'].values, q=list(range(10, 101, 10))).compute()
# Out:
# array([-114.,   41.,  150.,  279.,  491.,  741., 1009., 1644., -119.,
#        -119.])

# %%
# на перспективу:
df['amount'].describe(percentile=list(range(10, 101, 10))).compute()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-56-b36edd0af010> in <module>()
#       1 # на перспективу:
# ----> 2 df['amount'].describe(percentile=list(range(10, 101, 10))).compute()
#
# TypeError: describe() got an unexpected keyword argument 'percentile'

# %%
v = df['amount'].values

# %%
dask.persist(v)
# Out:
# (dask.array<values, shape=(nan,), dtype=int64, chunksize=(nan,)>,)

# %%
s = v.sum()

# %%
s.visualize()

# %%
df.describe(percentiles=[10, 50])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-24-9fc90c0dd9c7> in <module>()
# ----> 1 df.describe(percentiles=[10, 50])
#
# TypeError: describe() got an unexpected keyword argument 'percentiles'

# %% [markdown]
# 4) Нати 2 последовательно идующие транзакции имеющие наибольшую по модулю разность между значениями amount.

# %%
def diff_between_window(df, periods=1):
         before, after = (periods, 0) if periods > 0 else (0, -periods)
         return df.map_overlap(lambda df, periods=1: df.diff(periods),
                           periods, 0, periods=periods)

# %%
tr2 = diff_between_window(df['amount'], 1).abs().idxmax()
tr1 = tr2 - 1

# %%
dask.compute(tr1, tr2)
# Out:
# (461329, 461330)

# %% [markdown]
# 5) Для файлов json с отзывами с Amazon подсчиатать количество отзывов для каждой из оценок. Для подсчета количества отзывов использовать Dask.DataFrame .

# %%
reviews_json = dd.read_json(['C:\\Users\\161193\\Documents\\amazon-reviews\\reviews_Toys_and_Games_5.json.gz', 
                             'C:\\Users\\161193\Documents\\amazon-reviews\\reviews_Video_Games_5.json.gz'])

# %%
reviews_json.head()
# Out:
#          asin helpful  overall  \
# 0  0439893577  [0, 0]        5
# 1  0439893577  [1, 1]        4
# 2  0439893577  [1, 1]        5
# 3  0439893577  [0, 0]        5
# 4  0439893577  [1, 1]        4
#
#                                           reviewText   reviewTime  \
# 0  I like the item pricing. My granddaughter want...  01 29, 2014
# 1  Love the magnet easel... great for moving to d...  03 28, 2014
# 2  Both sides are magnetic.  A real plus when you...  01 28, 2013
# 3  Bought one a few years ago for my daughter and...   02 8, 2014
# 4  I have a stainless steel refrigerator therefor...   05 5, 2014
#
#        reviewerID    reviewerName  \
# 0  A1VXOAVRGKGEAK           Angie
# 1   A8R62G708TSCM         Candace
# 2  A21KH420DK0ICA  capemaychristy
# 3   AR29QK6HPFYZ4            dcrm
# 4   ACCH8EOML6FN5            DoyZ
#
#                                              summary  unixReviewTime
# 0                                     Magnetic board      1390953600
# ...

# %%
reviews_json.groupby('overall').overall.count().compute()
# Out:
# overall
# 1     19560
# 2     19961
# 3     44632
# 4     92249
# 5    222975
# Name: overall, dtype: int64

# %%
import pandas as pd
import numpy as np
import operator
import os
import dask
import dask.dataframe as dd

# %%
df = dd.read_csv(r'../data/accounts/accounts.*.csv')

# %%
df.head()
# Out:
#     id     names  amount
# 0  469  Patricia    1605
# 1  266     Sarah    2922
# 2  421    Hannah     324
# 3  321    Ingrid     166
# 4  497   Charlie    1745

# %% [markdown]
# 1) В account.*.csv найти имя, для которого встречается наибольшее количество положительных значений в столбце amount.

# %%
df.groupby(df.names).amount.count().compute()
# Out:
#          id     names  amount
# 0       469  Patricia    1605
# 1       266     Sarah    2922
# 2       421    Hannah     324
# 3       321    Ingrid     166
# 4       497   Charlie    1745
# 5       314    Hannah    1514
# 6       469  Patricia    1652
# 8       103    Yvonne    2331
# 9       123     Laura     357
# 10       19   Michael     147
# 11      329     Frank    6647
# 12      343    Yvonne    1046
# 13       53     Zelda     216
# 14      451  Patricia    2261
# 16      329     Frank    6490
# 17      109    Ursula     932
# 18      349   Michael     701
# 19      140   Michael    1752
# 20      468    Ursula       2
# 22      403     Wendy      38
# 23      478     Frank     129
# 24      128     Laura    2611
# 25       99   Charlie    4028
# 26      493     Edith    1365
# 27      480    Ingrid     926
# 29      246     Jerry    1685
# 30      481       Ray      20
# 31      274     Zelda     144
# 32      416   Charlie     336
# 33       52    Ursula    3769
# ...

# %%
df[df.amount > 0].groupby('names').amount.count().idxmax().compute()
# Out:
# 'Charlie'

# %% [markdown]
# 2) Эффективно создать csv файлы, содержащие данные из файлов `accounts.*.csv` к которым добавлен столбец, в котором содержится количество сотен из положительного значения amount и 0, если значение в amount отрицательное.

# %%
def get_hunderds(num):
    if num > 0:
        return int(num // 100)
    else:
        return 0

# %%
df['new'] = df.amount.apply(get_hunderds, meta=('new', 'i8'))

# %%
df.to_csv(r'new_accounts.*.csv')
# Out:
# ['data/new_accounts.0.csv',
#  'data/new_accounts.1.csv',
#  'data/new_accounts.2.csv',
#  'data/new_accounts.3.csv',
#  'data/new_accounts.4.csv',
#  'data/new_accounts.5.csv']

# %% [markdown]
# 3) Эффективно найти все 10 децилей для распределения значения amount.

# %%
import dask.array as da

# %%
da.percentile(df['amount'].values, q=list(range(10,101,10))).compute()
# Out:
# array([  -82.,    48.,   152.,   311.,   658.,   980.,  1413.,  1964.,
#         2804., 18049.])

# %% [markdown]
# 4) Найти 2 последовательно идующие транзакции имеющие наибольшую по модулю разность между значениями amount.

# %%
def diff_between_window(df, periods=1):
    before, after = (periods, 0) if periods > 0 else (0, -periods)
    return df.map_overlap(lambda df, periods=1: df.diff(periods), periods, 0, periods=periods)

# %%
tr2 = diff_between_window(df['amount'], 1).abs().idxmax()
tr1 = tr2 - 1

# %% [markdown]
# 5

# %%
data_amz = dd.read_json('../data/amazon-reviews/Toys_and_Games_5.json')

# %%
data_amz.group_by('overall').overall.count().compute()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-10-4275a3d0dff2> in <module>
# ----> 1 data_amz.group_by('overall').overall.count().compute()
#
# ~/.pyenv/versions/miniconda3-latest/envs/base_env/lib/python3.6/site-packages/dask/dataframe/core.py in __getattr__(self, key)
#    2527             return new_dd_object(merge(self.dask, dsk), name,
#    2528                                  meta, self.divisions)
# -> 2529         raise AttributeError("'DataFrame' object has no attribute %r" % key)
#    2530
#    2531     def __dir__(self):
#
# AttributeError: 'DataFrame' object has no attribute 'group_by'

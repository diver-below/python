# %% [markdown]
# 8) Задан произвольный массив numpy (например массив из 100 случайных числе от 0 до 1). Необходимо найти в нем число наиболее близкое к заданному.

# %%
import numpy as np

val_to_find = 0.6
a = np.random.random(size=100)
result_id = (np.abs(a-val_to_find)).argmin()
print(np.sort(a))
print(a[result_id])
# Out:
# [1.89166823e-04 1.03853194e-02 3.22379151e-02 6.37353574e-02
#  7.27201536e-02 7.52484539e-02 9.26954915e-02 9.67759092e-02
#  1.09293086e-01 1.38174486e-01 1.38812824e-01 1.58719056e-01
#  1.91534269e-01 2.04723430e-01 2.13513510e-01 2.16878852e-01
#  2.39493811e-01 2.50011293e-01 2.68851750e-01 2.71685593e-01
#  2.78522235e-01 2.82089440e-01 2.93035201e-01 3.02931666e-01
#  3.07343381e-01 3.10875513e-01 3.28563431e-01 3.47372800e-01
#  3.60711179e-01 3.71115254e-01 3.73792213e-01 3.76772659e-01
#  3.79070017e-01 3.92889954e-01 4.15414724e-01 4.25983536e-01
#  4.28127920e-01 4.30961855e-01 4.31159327e-01 4.44340633e-01
#  4.53296468e-01 4.54894729e-01 4.62593610e-01 4.63925874e-01
#  4.72195985e-01 4.73686137e-01 4.73739560e-01 4.79879958e-01
#  4.83319260e-01 4.85312483e-01 4.91750963e-01 5.01934021e-01
#  5.19444883e-01 5.33564682e-01 5.37752483e-01 5.37960152e-01
#  5.70566924e-01 5.84967991e-01 5.95070981e-01 5.97356375e-01
#  6.03191864e-01 6.09264948e-01 6.15730585e-01 6.18231324e-01
#  6.32028157e-01 6.48300356e-01 6.58276985e-01 6.68937343e-01
#  6.71206336e-01 6.75475765e-01 6.88590893e-01 6.89913164e-01
#  6.96293488e-01 6.99949278e-01 7.03102388e-01 7.03944571e-01
#  7.27185714e-01 7.51480550e-01 7.60119709e-01 7.68875028e-01
#  7.71226501e-01 7.72359208e-01 7.72461957e-01 7.89072274e-01
#  7.93273004e-01 8.48039760e-01 8.50952715e-01 8.57597824e-01
#  8.67960641e-01 8.70999418e-01 8.92790240e-01 8.95494171e-01
#  9.18108000e-01 9.31681476e-01 9.35873436e-01 9.46751733e-01
#  9.54718864e-01 9.80473343e-01 9.80731925e-01 9.85765535e-01]
# 0.5973563746325629

# %% [markdown]
# 9) При помощи прихотливого индексирования для двухмерного массива размерности (20, 20), состоящего из случайных целых чисел в пределах от 0 до 10 получить массив элементов находящихся на диагонали, проходящей над основной диагональю.

# %%
a = np.random.uniform(0, 10, size=(20,20))
row_indices = np.arange(0, 19)
col_indices = np.arange(1, 20)
print(a[row_indices,col_indices])
# Out:
# [1.20596947 9.05496226 2.65050744 7.35551139 4.39402984 0.14723119
#  7.29437735 2.45715906 4.56330044 4.10945303 9.90394172 0.72159221
#  7.19887022 4.02943883 3.67475096 1.96575764 0.31638504 1.31391919
#  8.80169892]

# %% [markdown]
# 10) Имеется массив из 10 названий городов. При помощи прихотливой индексации сгенерировать последовательность из 100 элементов представляющих случайный выбор из названий городов.

# %%
cities = np.array(["A", "B", "C", "D", "E", "F", "G", "H", "I", "J"])
indices = np.random.randint(0, 10, size=100)
cities[indices]
# Out:
# array(['C', 'H', 'H', 'F', 'I', 'F', 'E', 'C', 'J', 'J', 'C', 'E', 'F',
#        'I', 'D', 'J', 'J', 'I', 'I', 'I', 'C', 'D', 'J', 'E', 'A', 'E',
#        'J', 'H', 'G', 'H', 'A', 'G', 'J', 'D', 'B', 'F', 'C', 'C', 'H',
#        'F', 'B', 'E', 'D', 'C', 'F', 'A', 'A', 'A', 'H', 'H', 'C', 'I',
#        'A', 'F', 'A', 'F', 'A', 'H', 'I', 'D', 'H', 'C', 'I', 'C', 'A',
#        'E', 'B', 'E', 'G', 'D', 'D', 'J', 'C', 'I', 'C', 'H', 'F', 'A',
#        'B', 'B', 'F', 'J', 'E', 'D', 'I', 'I', 'I', 'G', 'H', 'I', 'C',
#        'E', 'C', 'E', 'E', 'E', 'G', 'J', 'A', 'E'], dtype='<U1')

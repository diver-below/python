# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv(r'datasets\sp500hst.txt', sep=',', header = None, names = ['time', 'indx', 'avg', 'max', 'min', 'last', 'vol'])

# %%
df.shape
# Out:
# (122574, 7)

# %%
df.head(15)
# Out:
#         time indx    avg      max      min   last    vol
# 0   20090821    A  25.60  25.6100  25.2200  25.55  34758
# 1   20090824    A  25.64  25.7400  25.3300  25.50  22247
# 2   20090825    A  25.50  25.7000  25.2250  25.34  30891
# 3   20090826    A  25.32  25.6425  25.1450  25.48  33334
# 4   20090827    A  25.50  25.5700  25.2300  25.54  70176
# 5   20090828    A  25.67  26.0500  25.6300  25.83  39694
# 6   20090831    A  25.45  25.7400  25.3100  25.68  51064
# 7   20090901    A  25.51  26.3300  25.4800  25.85  66422
# 8   20090902    A  25.97  25.9700  24.9600  25.22  64614
# 9   20090903    A  25.47  25.5400  25.0000  25.29  46369
# 10  20090904    A  25.37  25.9200  25.1475  25.86  32556
# 11  20090909    A  26.31  27.1900  26.1600  27.15  36764
# 12  20090910    A  27.08  27.8800  26.9400  27.86  42987
# 13  20090911    A  27.88  28.1600  27.7500  28.05  43907
# 14  20090914    A  27.86  28.1800  27.6400  28.10  35156

# %%
df.groupby(['indx'])['avg','min','max', 'last'].mean()
# Out:
#              avg         min         max        last
# indx
# A      30.234857   29.866467   30.567838   30.246143
# AA     13.086959   12.842954   13.275341   13.047345
# AAPL  221.342427  218.409411  223.556147  221.125341
# ABC    27.432122   27.126983   27.683660   27.429347
# ABT    50.996776   50.555472   51.365541   50.986490
# ACE    52.506316   52.031581   53.021430   52.567895
# ACS    54.724045   54.238415   55.205028   54.723818
# ADBE   33.357181   32.936090   33.741407   33.352469
# ADI    29.082918   28.665330   29.412684   29.059959
# ADM    28.966347   28.644947   29.267488   28.957898
# ADP    41.739136   41.338874   42.078807   41.766934
# ADSK   26.924380   26.542785   27.314596   26.955919
# AEE    25.813959   25.578957   26.031407   25.833102
# AEP    33.397980   33.087239   33.656317   33.403878
# AES    12.178612   11.961024   12.359245   12.158939
# AET    29.864915   29.406918   30.312937   29.843959
# AFL    47.186898   46.462483   47.807477   47.168776
# ...

# %%
df.groupby(['indx'])['avg'].mean()
# Out:
# indx
# A        30.234857
# AA       13.086959
# AAPL    221.342427
# ABC      27.432122
# ABT      50.996776
# ACE      52.506316
# ACS      54.724045
# ADBE     33.357181
# ADI      29.082918
# ADM      28.966347
# ADP      41.739136
# ADSK     26.924380
# AEE      25.813959
# AEP      33.397980
# AES      12.178612
# AET      29.864915
# AFL      47.186898
# AGN      60.266755
# AIG      35.394276
# AIV      17.474571
# AIZ      32.947776
# AKAM     30.485658
# AKS      19.006382
# ALL      30.321429
# ALTR     23.424115
# AMAT     12.984486
# AMD       7.711184
# AMGN     56.774074
# AMP      39.577755
# AMT      41.552816
#            ...
# WDC      37.173694
# WEC      49.098877
# WFC      28.551020
# WFMI     33.426687
# WFR      13.345918
# WHR      84.085429
# WIN      10.577459
# WLP      55.636816
# WM       32.710044
# WMB      20.566327
# WMT      52.431938
# WPI      39.821796
# WPO     447.179143
# WU       17.571755
# WY       39.147980
# WYE      48.232895
# ...

# %%
#5.1
df.where((df['min']<df['avg']) & (df['min']<df['max'])).shape
# Out:
# (122574, 7)

# %%
#5
df[['avg','max','min']].where(df['time']>20100801).max()
# Out:
# avg    505.850
# max    508.600
# min    503.559
# dtype: float64

# %%
#6
df['vol'].where(df['avg']>50).mean()
# Out:
# 36467.08664563617

# %%
#7
excel = pd.read_excel(r'C:\Users\miair\Documents\Python\Сем big data\datasets\excel-comp-data.xlsx')

# %%
excel.head()
# Out:
#    account                         name                                street  \
# 0   211829   Kerluke, Koepp and Hilpert                    34456 Sean Highway
# 1   320563               Walter-Trantow                     1311 Alvis Tunnel
# 2   648336   Bashirian, Kunde and Price  62184 Schamberger Underpass Apt. 231
# 3   109996  D'Amore, Gleichner and Bode           155 Fadel Crescent Apt. 144
# 4   121213                Bauch-Goldner                   7274 Marissa Common
#
#               city          state  postal-code     Jan     Feb    Mar
# 0       New Jaycob          Texas        28752   10000   62000  35000
# 1    Port Khadijah  NorthCarolina        38365   95000   45000  35000
# 2   New Lilianland           Iowa        76517   91000  120000  35000
# 3       Hyattburgh          Maine        46021   45000  120000  10000
# 4  Shanahanchester     California        49681  162000  120000  35000

# %%
#8
excel.groupby(excel['state']).count()
# Out:
#                account  name  street  city  postal-code  Jan  Feb  Mar
# state
# Arkansas             1     1       1     1            1    1    1    1
# California           1     1       1     1            1    1    1    1
# Delaware             1     1       1     1            1    1    1    1
# Idaho                1     1       1     1            1    1    1    1
# Iowa                 2     2       2     2            2    2    2    2
# Maine                1     1       1     1            1    1    1    1
# Mississipi           1     1       1     1            1    1    1    1
# NorthCarolina        1     1       1     1            1    1    1    1
# NorthDakota          1     1       1     1            1    1    1    1
# Pennsylvania         1     1       1     1            1    1    1    1
# RhodeIsland          2     2       2     2            2    2    2    2
# Tenessee             1     1       1     1            1    1    1    1
# ...

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# 1) Задание: загрузить данные из файлов (приложены к письму):
# * excel-comp-data.xlsx
# * sp500hst.txt

# %%
data = pd.read_excel("excel-comp-data.xlsx", sep=';')

# %%
data.head()
# Out:
#    account                         name                                street  \
# 0   211829   Kerluke, Koepp and Hilpert                    34456 Sean Highway
# 1   320563               Walter-Trantow                     1311 Alvis Tunnel
# 2   648336   Bashirian, Kunde and Price  62184 Schamberger Underpass Apt. 231
# 3   109996  D'Amore, Gleichner and Bode           155 Fadel Crescent Apt. 144
# 4   121213                Bauch-Goldner                   7274 Marissa Common
#
#               city          state  postal-code     Jan     Feb    Mar
# 0       New Jaycob          Texas        28752   10000   62000  35000
# 1    Port Khadijah  NorthCarolina        38365   95000   45000  35000
# 2   New Lilianland           Iowa        76517   91000  120000  35000
# 3       Hyattburgh          Maine        46021   45000  120000  10000
# 4  Shanahanchester     California        49681  162000  120000  35000

# %%
dataCSV = pd.read_csv("sp500hst.txt", header = None)
dataCSV.head()
# Out:
#           0  1      2        3       4      5      6
# 0  20090821  A  25.60  25.6100  25.220  25.55  34758
# 1  20090824  A  25.64  25.7400  25.330  25.50  22247
# 2  20090825  A  25.50  25.7000  25.225  25.34  30891
# 3  20090826  A  25.32  25.6425  25.145  25.48  33334
# 4  20090827  A  25.50  25.5700  25.230  25.54  70176

# %% [markdown]
# 2) Загрузить данные из файла sp500hst.txt, обозначить столбцы (в соответствии с содержимым).

# %%
dataCSV2 = dataCSV.rename(columns={0:"Date", 1:"Tiker", 2:"Open_price", 
                                   3:"Min_per_day", 4:"Max_per_day", 
                                   5:"Close_price", 6:"V"})
dataCSV2.head()
# Out:
#        Date Tiker  Open_price  Min_per_day  Max_per_day  Close_price      V
# 0  20090821     A       25.60      25.6100       25.220        25.55  34758
# 1  20090824     A       25.64      25.7400       25.330        25.50  22247
# 2  20090825     A       25.50      25.7000       25.225        25.34  30891
# 3  20090826     A       25.32      25.6425       25.145        25.48  33334
# 4  20090827     A       25.50      25.5700       25.230        25.54  70176

# %%
dataCSV.columns = ["Date", "Tiker", "Open_price", "Min_per_day", 
                   "Max_per_day", "Close_price", "V"]
dataCSV.head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-28-1a006cb5a743> in <module>()
#       1 dataCSV.columns = ["Date", "Tiker", "Open_price", "Min_per_day",
# ----> 2                    "Max_per_day", "Close_price", "V"]
#       3 dataCSV.head()
#
# C:\ProgramData\Anaconda3.1\lib\site-packages\pandas\core\generic.py in __setattr__(self, name, value)
#    2981         try:
#    2982             object.__getattribute__(self, name)
# -> 2983             return object.__setattr__(self, name, value)
#    2984         except AttributeError:
#    2985             pass
#
# pandas\_libs\src\properties.pyx in pandas._libs.lib.AxisProperty.__set__ (pandas\_libs\lib.c:45103)()
#
# C:\ProgramData\Anaconda3.1\lib\site-packages\pandas\core\generic.py in _set_axis(self, axis, labels)
#     469
#     470     def _set_axis(self, axis, labels):
# --> 471         self._data.set_axis(axis, labels)
#     472         self._clear_item_cache()
#     473
#
# C:\ProgramData\Anaconda3.1\lib\site-packages\pandas\core\internals.py in set_axis(self, axis, new_labels)
#    2834             raise ValueError('Length mismatch: Expected axis has %d elements, '
#    2835                              'new values have %d elements' %
# -> 2836                              (old_len, new_len))
#    2837
#    2838         self.axes[axis] = new_labels
#
# ValueError: Length mismatch: Expected axis has 8 elements, new values have 7 elements

# %%
ar1 = np.array(["Date", "Tiker", "Open_price", "Max_per_day", "Min_per_day", "Close_price", "V"])
dataCSV = pd.read_csv("sp500hst.txt", header = None, names = ar1)
dataCSV.head()
# Out:
#        Date Tiker  Open_price  Max_per_day  Min_per_day  Close_price      V
# 0  20090821     A       25.60      25.6100       25.220        25.55  34758
# 1  20090824     A       25.64      25.7400       25.330        25.50  22247
# 2  20090825     A       25.50      25.7000       25.225        25.34  30891
# 3  20090826     A       25.32      25.6425       25.145        25.48  33334
# 4  20090827     A       25.50      25.5700       25.230        25.54  70176

# %%
dataCSV.head()
# Out:
#        Date Tiker  Open_price  Min_per_day  Max_per_day  Close_price      V
# 0  20090821     A       25.60      25.6100       25.220        25.55  34758
# 1  20090824     A       25.64      25.7400       25.330        25.50  22247
# 2  20090825     A       25.50      25.7000       25.225        25.34  30891
# 3  20090826     A       25.32      25.6425       25.145        25.48  33334
# 4  20090827     A       25.50      25.5700       25.230        25.54  70176

# %% [markdown]
# 3.1) Создать столбец со значеними средними, между значением дневного минимума и максимума.

# %%
dataCSV["Average_per_day"] = (dataCSV["Min_per_day"]+dataCSV["Max_per_day"])/2
dataCSV.head()
# Out:
#        Date Tiker  Open_price  Max_per_day  Min_per_day  Close_price      V  \
# 0  20090821     A       25.60      25.6100       25.220        25.55  34758
# 1  20090824     A       25.64      25.7400       25.330        25.50  22247
# 2  20090825     A       25.50      25.7000       25.225        25.34  30891
# 3  20090826     A       25.32      25.6425       25.145        25.48  33334
# 4  20090827     A       25.50      25.5700       25.230        25.54  70176
#
#    Average_per_day
# 0         25.41500
# 1         25.53500
# 2         25.46250
# 3         25.39375
# 4         25.40000

# %%
dataCSV['new']=(dataCSV['Min_per_day']+dataCSV['Max_per_day'])/2
dataCSV.head()
# Out:
#        Date Tiker  Open_price  Min_per_day  Max_per_day  Close_price      V  \
# 0  20090821     A       25.60      25.6100       25.220        25.55  34758
# 1  20090824     A       25.64      25.7400       25.330        25.50  22247
# 2  20090825     A       25.50      25.7000       25.225        25.34  30891
# 3  20090826     A       25.32      25.6425       25.145        25.48  33334
# 4  20090827     A       25.50      25.5700       25.230        25.54  70176
#
#         new
# 0  25.41500
# 1  25.53500
# 2  25.46250
# 3  25.39375
# 4  25.40000

# %% [markdown]
# 3.2) Рассчитать среднее значение показателей для каждого из столбцов 3-6.

# %%
r = dataCSV.loc[:,'Open_price':'Close_price'].mean()
print(f'type={type(r)}, \n value: \n {r}')
# Out:
# type=<class 'pandas.core.series.Series'>,
#  value:
#  Open_price     42.595458
# Max_per_day    43.102243
# Min_per_day    42.054464
# Close_price    42.601865
# dtype: float64

# %% [markdown]
# 4.1) Создать DataFrame состоящий из строк относящихся только к 13 августа 2010 года.

# %%
data_41 = dataCSV2.copy()
data_41 = data_41[data_41.Date == 20100813]
data_41
# Out:
#             Date Tiker  Open_price  Min_per_day  Max_per_day  Close_price  \
# 240     20100813     A       27.39      27.8500       27.300        27.35
# 485     20100813    AA       10.70      10.7900       10.575        10.64
# 726     20100813  AAPL      251.03     251.8800      249.090       249.10
# 971     20100813   ABC       29.01      29.1300       28.690        29.04
# 1216    20100813   ABT       50.13      50.2600       49.910        50.06
# 1273    20100813   ACE       52.16      53.8300       52.160        53.42
# 1626    20100813  ADBE       27.99      28.3400       27.860        28.01
# 1871    20100813   ADI       28.16      28.4200       28.020        28.07
# 2116    20100813   ADM       30.59      30.7800       29.990        30.05
# 2359    20100813   ADP       39.98      40.1300       39.720        39.79
# 2601    20100813  ADSK       28.50      29.6800       28.060        28.12
# 2846    20100813   AEE       26.57      27.6700       26.420        27.58
# 3091    20100813   AEP       35.17      35.7800       35.170        35.52
# 3336    20100813   AES       10.52      10.9500       10.510        10.62
# 3581    20100813   AET       27.99      28.2600       27.800        28.14
# 3826    20100813   AFL       48.59      48.7200       47.720        47.76
# 4071    20100813   AGN       63.01      63.9300       63.010        63.66
# 4316    20100813   AIG       37.20      37.5000       36.530        36.67
# 4561    20100813   AIV       20.24      20.5200       20.070        20.26
# 4806    20100813   AIZ       36.78      37.4700       36.740        37.01
# 5049    20100813  AKAM       43.76      44.7200       43.330        44.22
# 5294    20100813   AKS       13.26      13.4000       12.950        13.07
# 5539    20100813   ALL       28.16      28.4900       28.040        28.10
# 5782    20100813  ALTR       25.30      25.5000       24.940        24.94
# 6025    20100813  AMAT       11.12      11.3400       11.110        11.17
# 6270    20100813   AMD        6.60       6.7200        6.470         6.49
# 6514    20100813  AMGN       54.39      55.3600       54.180        55.02
# 6758    20100813   AMP       42.69      43.2500       42.170        42.20
# 7003    20100813   AMT       45.80      46.0600       45.530        45.76
# 7246    20100813  AMZN      126.07     127.4800      124.260       124.69
# ...          ...   ...         ...          ...          ...          ...
# 114996  20100813    VZ       30.16      30.2900       29.915        30.03
# 115241  20100813   WAG       27.99      28.3190       27.900        28.17
# 115486  20100813   WAT       62.84      63.3200       62.350        62.39
# 115731  20100813   WDC       24.21      24.7000       24.160        24.46
# 115976  20100813   WEC       54.74      55.5900       54.740        55.22
# 116221  20100813   WFC       25.99      26.3000       25.810        25.84
# 116464  20100813  WFMI       36.05      36.7100       35.820        36.42
# 116709  20100813   WFR       10.35      10.5700       10.260        10.47
# 116954  20100813   WHR       77.99      77.9900       76.430        76.74
# 117198  20100813   WIN       11.31      11.4300       11.260        11.33
# 117443  20100813   WLP       51.31      52.0400       50.810        51.79
# 117688  20100813    WM       33.06      33.2400       33.000        33.01
# 117933  20100813   WMB       19.37      19.6800       19.370        19.44
# 118178  20100813   WMT       50.33      50.7400       50.000        50.40
# 118423  20100813   WPI       41.40      41.9700       41.290        41.73
# 118668  20100813   WPO      347.95     351.7100      337.850       343.48
# 118913  20100813    WU       15.98      16.1700       15.950        15.98
# 119158  20100813    WY       16.41      16.6100       16.350        16.36
# 119441  20100813   WYN       24.79      25.1900       24.680        24.88
# 119678  20100813  WYNN       86.81      88.2400       86.700        87.26
# 119923  20100813     X       45.22      46.1350       44.990        45.10
# 120168  20100813   XEL       22.25      22.6400       22.240        22.42
# 120413  20100813    XL       17.96      18.3500       17.910        18.00
# 120656  20100813  XLNX       25.44      25.6600       25.030        25.04
# 120901  20100813   XOM       59.96      60.4500       59.800        59.91
# 121385  20100813   XRX        9.05       9.2200        8.980         9.01
# 121835  20100813  YHOO       13.82      13.9550       13.760        13.83
# 122080  20100813   YUM       40.80      41.0399       40.620        40.85
# 122324  20100813  ZION       20.17      20.4300       19.840        19.89
# 122569  20100813   ZMH       51.72      51.9000       51.380        51.44
#
#              V
# 240      24469
# 485     154397
# 726     126738
# 971      16196
# 1216     50879
# 1273     23890
# 1626     66254
# 1871     27100
# 2116     60221
# 2359     21913
# 2601    112191
# 2846     50249
# 3091     31585
# 3336     43780
# 3581     25036
# 3826     36596
# 4071     11899
# 4316     32072
# 4561     16732
# 4806     10168
# 5049     60503
# 5294     55031
# 5539     32407
# 5782     69416
# 6025    159012
# 6270    243344
# 6514     55147
# 6758     23411
# 7003     17890
# 7246     39835
# ...        ...
# 114996  146395
# 115241   70324
# 115486   11458
# 115731   42035
# 115976    6795
# 116221  254941
# 116464   27439
# 116709   44291
# 116954   15916
# 117198   38994
# 117443   23225
# 117688   12415
# 117933   29389
# 118178  100983
# 118423    9236
# 118668    1681
# 118913   35446
# 119158   21853
# 119441   12417
# 119678   17464
# 119923   80616
# 120168   49735
# 120413   35702
# 120656   82297
# 120901  146562
# 121385   89064
# 121835   78455
# 122080   20055
# 122324   25193
# 122569   14561
#
# [499 rows x 7 columns]

# %%
data_date_fltr = dataCSV[dataCSV.Date == 20100813]
data_date_fltr.head()
# Out:
#           Date Tiker  Open_price  Min_per_day  Max_per_day  Close_price  \
# 240   20100813     A       27.39        27.85       27.300        27.35
# 485   20100813    AA       10.70        10.79       10.575        10.64
# 726   20100813  AAPL      251.03       251.88      249.090       249.10
# 971   20100813   ABC       29.01        29.13       28.690        29.04
# 1216  20100813   ABT       50.13        50.26       49.910        50.06
#
#            V       new
# 240    24469   27.5750
# 485   154397   10.6825
# 726   126738  250.4850
# 971    16196   28.9100
# 1216   50879   50.0850

# %%
data_date_fltr.shape
# Out:
# (499, 8)

# %% [markdown]
# 4.1.2) Из DataFrame, созданного в 4.1, cоздать серию из 30 первых имен

# %%
data_41['Tiker'].iloc[29]
# Out:
# 'AMZN'

# %%
data_41['Tiker'].iloc[:30]
# Out:
# 240        A
# 485       AA
# 726     AAPL
# 971      ABC
# 1216     ABT
# 1273     ACE
# 1626    ADBE
# 1871     ADI
# 2116     ADM
# 2359     ADP
# 2601    ADSK
# 2846     AEE
# 3091     AEP
# 3336     AES
# 3581     AET
# 3826     AFL
# 4071     AGN
# 4316     AIG
# 4561     AIV
# 4806     AIZ
# 5049    AKAM
# 5294     AKS
# 5539     ALL
# 5782    ALTR
# 6025    AMAT
# 6270     AMD
# 6514    AMGN
# 6758     AMP
# 7003     AMT
# 7246    AMZN
# Name: Tiker, dtype: object

# %%
res4_1_2 = pd.Series(data_date_fltr.Tiker.iloc[:30])
print(res4_1_2)
# Out:
# 240        A
# 485       AA
# 726     AAPL
# 971      ABC
# 1216     ABT
# 1273     ACE
# 1626    ADBE
# 1871     ADI
# 2116     ADM
# 2359     ADP
# 2601    ADSK
# 2846     AEE
# 3091     AEP
# 3336     AES
# 3581     AET
# 3826     AFL
# 4071     AGN
# 4316     AIG
# 4561     AIV
# 4806     AIZ
# 5049    AKAM
# 5294     AKS
# 5539     ALL
# 5782    ALTR
# 6025    AMAT
# 6270     AMD
# 6514    AMGN
# 6758     AMP
# 7003     AMT
# 7246    AMZN
# Name: Tiker, dtype: object

# %% [markdown]
# 4.2) Из DataFrame, созданного в 4.1, создать новый DataFrame индексом в котором являются имена тикеров.

# %%
data_42_2 = data_41.copy()
data_42_2.set_index('Tiker', inplace=True)
data_42_2.head()
# Out:
#            Date  Open_price  Min_per_day  Max_per_day  Close_price       V
# Tiker
# A      20100813       27.39        27.85       27.300        27.35   24469
# AA     20100813       10.70        10.79       10.575        10.64  154397
# AAPL   20100813      251.03       251.88      249.090       249.10  126738
# ABC    20100813       29.01        29.13       28.690        29.04   16196
# ABT    20100813       50.13        50.26       49.910        50.06   50879

# %%
data_42 = data_41.copy()
data_42.index = data_41.Tiker
data_42 = data_42.drop("Tiker", axis=1)
data_42.head()
# Out:
#            Date  Open_price  Min_per_day  Max_per_day  Close_price       V
# Tiker
# A      20100813       27.39        27.85       27.300        27.35   24469
# AA     20100813       10.70        10.79       10.575        10.64  154397
# AAPL   20100813      251.03       251.88      249.090       249.10  126738
# ABC    20100813       29.01        29.13       28.690        29.04   16196
# ABT    20100813       50.13        50.26       49.910        50.06   50879

# %%
t42=pd.DataFrame(data=data_date_fltr)
t42.index=data_date_fltr['Tiker']
t42.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-53-6c3e0ff7d2a4> in <module>()
# ----> 1 t42=pd.DataFrame(data=data_date_fltr)
#       2 t42.index=data_date_fltr['Tiker']
#       3 t42.head()
#
# NameError: name 'data_date_fltr' is not defined

# %%
t422=pd.DataFrame(data=data_date_fltr)
t422.set_index('Tiker', inplace=True)
t422.head()
# Out:
#            Date  Open_price  Min_per_day  Max_per_day  Close_price       V  \
# Tiker
# A      20100813       27.39        27.85       27.300        27.35   24469
# AA     20100813       10.70        10.79       10.575        10.64  154397
# AAPL   20100813      251.03       251.88      249.090       249.10  126738
# ABC    20100813       29.01        29.13       28.690        29.04   16196
# ABT    20100813       50.13        50.26       49.910        50.06   50879
#
#             new
# Tiker
# A       27.5750
# AA      10.6825
# AAPL   250.4850
# ABC     28.9100
# ABT     50.0850

# %% [markdown]
# 4.3) Создать DataFrame состоящий из строк относящихся только тикеру ALTR.

# %% [markdown]
# 4.4) Из DataFrame, созданного в 4.3, создать DataFrame индексом в котором являются даты.

# %% [markdown]
# 4.5) В DataFrame, созданном в 4.3, добавить столбец, содержащий только число месяца, к которому относится дата.

# %% [markdown]
# 4.5.1) Создать DataFrame состоящий из строк относящихся только тикеру WAT и объединить его с DataFrame для ALTR.

# %% [markdown]
# 4.5.2) Создать DataFrame в котором присутствует столбец, отражающий разницу в объемах торгов по WAT и ALTR в одинаковые дни и содержит исходные данны об объеме трогов этими акциями.

# %% [markdown]
# 4.6) В DataFrame добавить столбец, содержащий только число месяца, к которому относится дата.
#
# 4.7) Из DataFrame выбрать только строки, относящиеся к 13 числу месяца.

# %% [markdown]
# 4) Выяввиь столбцы содержащие минимальные и максимальные значения (если такие столбцы есть). (Проверить, есть ли среди столбцов, столбец с минимальным значением курса акций.)

# %% [markdown]
# 5) По данным из 'sp500hst.txt' при помощи Pandas расчитать максимальные значения в 3-6 столбца для дат после 20100801
#
# 6) По данным из 'sp500hst.txt' при помощи Pandas расчитать средний объем торгов (обеъм торгов - в последнем столбце) при значениях 3го столбца больше 50.

# %% [markdown]
# 7) Добавить столбец с расшифровкой названия тикера используя данные из файла sp_data2.csv . В случае нехватки данных об именах тикеров корректно обработать их.
#
# 8) Вывести тикеры, для которых не были найдены рсшифровки.

# %% [markdown]
# 9) Рассчитать суммарный объем торгов (столбец 7) для для одинаковых значений (тикеров) из столбца 2
#
# 9.2) Для каждого тикера подсчитать, сколько раз он встречается.
#
# 10) Расчитать среднее значение показателей для каждого из столбцов 3-6 для одинаковых значений (тикеров) из столбца 2 и сохранить в новом DataFrame
#
# 11) Добавить в DataFrame новый столбец, содержащий объем торгов (столбец 7), нормированный по среднему значению объема торгов для данного тикера.

# %% [markdown]
# 2.7) Задание: загрузить данные из файла (приложен к письму) 'excel-comp-data.xlsx'
#
# 2.8) Задание: сколько строк для каждого из штатов есть в датафрэйме?

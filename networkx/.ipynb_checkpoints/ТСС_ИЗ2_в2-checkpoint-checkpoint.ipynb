# %% [markdown]
# __Задача #1__
#
# _По материалам лекции 3 и 4_
#
# Используя данные эмперической сети (предпочтительно отражающей социальные взаимодействия) имеющий не менее 200 и не более 1000 узлов выявить слабые связи (weak ties) в сети. Использовать для решения один из изученных алгоритмов выявления сообществ в сетях. Наглядно визуализировать результат:
# * показать слабые связи на изображении сети
# * дать на изображении основание для выбора данных связей в качестве слабых связей

# %% [markdown]
# __Задача #2__
#
# _По материалам лекции 3 и 4_
#
# Используя функцию построения случайного геометрического графа (см: https://en.wikipedia.org/wiki/Random_geometric_graph ) (можно реализовать функцию самостоятельно или использовать готовую) построить 10 вариантов СГГ для 225 точек со случайными координатами на прямоугольнике с углами: (0,0), (1,1) с различными значениям $r$.
#
# Реализовать алгоритм локальной навигации в СГГ (аналогично алгоритму для модели Клейнберга, для выбора наилучшего варианта использовать координаты узлов в прямоугольнике) и визуализировать его результаты.
#
# Для каждого из 10 вариантов СГГ с разным $r$ набрать статистику средней длины пути, построенного с помощью локальной навигации, между произвольными узлами сети. Показать на графике 4 квартиля длины пути и долю не завршенных путей (алгоритм не приводит к целевому узлу) в зависимости от $r$ в СГГ.

# %% [markdown]
# __Задача #3__
#
# _По материалам лекции 3_
#
# Релизовать функцию построения u,v цветка. Функция принимает три целочисленных параметра $u$ (длина 1го пути, замещающего удаляемое ребро), $v$ (длина 2го пути, замещающего удаляемое ребро) и  $n$ (количество шагов построения). Функция обязательно должна работать в том числе и для $u$ и $v$ > 2.
#
# <center>
# <img src="./img/1_2_fl.png" alt="1,2 цветок" style="width: 200px;"/><br/>
#     <em class="ex"></em> <b>1,2 цветок</b>
# </center>
#
#
# <center>
# <img src="./img/2_2_fl.png" alt="2,2 цветок" style="width: 200px;"/><br/>
#     <em class="ex"></em> <b>2,2 цветок</b>
# </center>
#
# Визуально продемонстрировать корректную работу функции.
#
# Построить график средней длины пути в цветах в зависимости от $n$ ($n \in [1, 10]$) для 4х видов цветов (т.е. для разных u и v, в т.ч. и больших 2).

# %% [markdown]
# __Задача #4__
#
# _По материалам лекции 5 и 6_
#
# Реализовать компьютерную симуляцию модели SIR:
#
# * Логика модели:
#     * каждый узел находится в одном из двух состояний $\{ S, I, R\}$
#     * на 0-м шаге 1 узел устанавливаются в состояние $I$ (остальные - в $S$)
#     * На каждом шаге каждый из инфецированных узлов с вероятностю $\beta$ заражает каждый из связанных с ним уязвимых узлов
#     * Каждый инфецированный узел остается инфецированным $\tau_\gamma =1/\gamma$ временных шагов, после чего переходит в состояние $R$ и не может быть вновь инфецированным. Кроме того узлы в состоянии $R$ не распространяют инфекцию.
#
# С помощью визуализации показать корректную работу модели.
#
# Используя данные эмперической сети (предпочтительно отражающей социальные взаимодействия) имеющий не менее 200 и не более 1000 узлов провести 100 симуляций эпидемии. Для каждого узла сети рассичтать среднее время (в шагах модели) до инфицирования. Построить 4 графика зависимости среднего времени до инфецирования от 4 изученных метрик центральности.

# %% [markdown]
# __Задача #5__
#
# _По материалам лекции 4 и 5_
#
# Реализовать компьютерную симуляцию модели SIR:
#
# * Логика модели:
#     * каждый узел находится в одном из двух состояний $\{ S, I, R\}$
#     * на 0-м шаге 1 узел устанавливаются в состояние $I$ (остальные - в $S$)
#     * На каждом шаге каждый из инфецированных узлов с вероятностю $\beta$ заражает каждый из связанных с ним уязвимых узлов
#     * Каждый инфецированный узел остается инфецированным $\tau_\gamma =1/\gamma$ временных шагов, после чего переходит в состояние $R$ и не может быть вновь инфецированным. Кроме того узлы в состоянии $R$ не распространяют инфекцию.
#
# С помощью визуализации показать корректную работу модели.
#
# Рассмотреть эпидемию на примере эмперической сети (предпочтительно отражающей социальные взаимодействия) имеющий не менее 100 и не более 400 узлов. Используя один из изученных алгоритмов выявления сообщества в сетях разбить сеть на сообщества. Проведя не менее 1000 вычислительных экспериментов опредлить распределние случайной величны "шаг эпедимии, на которой заболевание покинуло сообщество, в котором зародилось" для каждого сообщества и для сети в целом.

# %% [markdown]
# __Задача #6__
#
# _По материалам лекции 6_
#
# Самостоятельно реализовать функцию определения центральности _СВЯЗИ_ по посреднечеству (можно использовать функции, определяющие кратчайший путь и длину пути между узлами). Сравнить реализации собственной и встроенной в NetworkX функции. Визуализировать рзамером (толщиной связи) центроальность связи по посреднечеству для 3х эмпирических сетей.

# %% [markdown]
# __Задача #7__
#
# _По материалам лекции 3_
#
# Используя функцию построения случайного геометрического графа (см: https://en.wikipedia.org/wiki/Random_geometric_graph ) (можно реализовать функцию самостоятельно или использовать готовую) построить 10 вариантов СГГ для 225 точек со случайными координатами на прямоугольнике с углами: (0,0), (1,1) с различными значениям $r$.
#
# ($r$ выбираем чтообы среднее количество связей было близко к 15)
#
# Провести пересвязывание 10% связей (использовать пересвязывание, сохраняющее степень узлов, аналогично используемому в алгоритме латтисизации).
#
# Реализовать алгоритм геолаттисизации (latticization), в качестве метрики расстояния использовать расстояние узлов на прямоугольнике.
#
# Визуализировать:
# * исходный СГГ
# * СГГ после пересвязывания
# * СГГ после геолаттисизации

# %% [markdown]
# __Задача #8__
#
# _По материалам лекции 4_
#
# Реализовать базовый алгоритм расстановки меток с использованием случайного блуждания. Применить его для эмперического графа, содержащего не менее 70 и не более 200 уц
#
# Используя алгоритм Гирвана-Ньюмена разбить эмпирический граф на два сообщества. Выбрав два узла из разны сообществ провести случайное блуждание из этих узлов и выбрать принадлежность каждого из узлов к одному из двух сообеств по близости в результате блуждания.
# Визуализировать результаты:
# * разибиения на 2 сообщества с помощью алгоритма Гирвана-Ньюмена
# * результаты случайного блуждания из 1 центра
# * результаты случайного блуждания из 2 центра
# * резульатты выбора сообщества в результате случайного блуждания

# %% [markdown]
# ## Лекция 2

# %% [markdown]
# __Задача #1 (2.1)__
#
# Рализовать алгоритм предпочтительного присоединения с целочисленными параметрами $n_0$, $m$, $t$.
# * $n_0$ - количество узлов в исходной сети (считаем, что исходная сеть является полным графом);
# * $m$ - количество связей у каждого вновь добавляемого узла;
# * $t$ - количество итераций по добоавлению нового узла.
# Проверить корректность алгоритма с помощью анализа распределения степеней узлов сгенерированной сети.

# %% [markdown]
# __Задача #2 (2.2)__
#
# С помощью реализации модели предпочтительного присоединения Барабаши-Альберта предложенной в NetworkX построить сеть с $N>2000$. Визуализировать ее распределение степеней узлов. Найти угол наклона графика распределения для построенной сети (и, соответственно, параметр $\gamma$) с помощью ММП (для оптимизации параметра можно использовать простой перебор).
#
# Можно использовать функции отсюда: https://www.statsmodels.org/devel/dev/generated/statsmodels.base.model.GenericLikelihoodModel.html (при желании и из других библиотек).

# %% [markdown]
# __Задача #3 (2.3)__
#
# Рализовать алгоритм растущего случайного графа. Проверить корректность алгоритма с помощью анализа распределения степеней узлов сгенерированной сети.

# %% [markdown]
# ## Лекция 3

# %% [markdown]
# __Задача #4 (3.1)__
#
# Реализовать алгоритм латтисизации (latticization). Визуализировать матрицу инцидентности исходной и латтисизированной сети (аналогично изображению в лекции).

# %% [markdown]
# __Задача #5 (3.2)__
#
# Реализовать алгоритм локальной навигации в модели Клейнберга и визуализировать его результаты (на изображении сети показать путь построенный с помощью навигации) и построить график, показывающий зависимость расстояния до целевого узла в зависимости от номера шага алгоритма. Показать не менее 3х сценариев на 3х решетка с разным показателем $\alpha$: $\{0, 1, 2\}$

# %% [markdown]
# __Задача #6 (3.3)__
#
# Реализовать функцию пересвязывания связей в произвольной сети с заданной вероятностю $p$. Вероятность $p$ разыгрывается для каждой связи, если принято решение о пересвязывании, один из двух узлов данной связи меняется на произвольный узел сети (нужна проверка на попытку создать повторную связь). Сеть для пересвязывания и $p$ - параметры функции, пересвязанная сеть - возвращаемое значение.
#
# Выбрать 2 реальные сети сравнимого размера с большой и маленькой среденей длиной пути. С помощью 3\.3\.5\. провести для этих 2 сетей последовательность пересвязываний (не менее 15) с $p$ возрастающим в геометрической прогерссии. Реализовать последовательность пересвязываний так, чтобы следующее пересвязывание (с большей вероятностью $p$) включало все передыдущие резульаты пересвязывания. Для каждой сети ппостроить на одном графике относительные изменения коэффициента кластеризации и средней длины пути (график, аналогичный приведенному в лекции).

# %% [markdown]
# __Задача #7 (3.4)__
#
# Реализовать функцию построения случайного геометрического графа (см: https://en.wikipedia.org/wiki/Random_geometric_graph ).
#
# * Построить СГГ для 225 точек со случайными координатами на прямоугольнике с углами: (0,0), (1,1) ($r$ выбираем чтообы среднее количество связей было близко к 15)
#
# Реализовать функцию пересвязывания связей в произвольной сети с заданной вероятностю $p$. Вероятность $p$ разыгрывается для каждой связи, если принято решение о пересвязывании, один из двух узлов данной связи меняется на произвольный узел сети (нужна проверка на попытку создать повторную связь). Сеть для пересвязывания и $p$ - параметры функции, пересвязанная сеть - возвращаемое значение.
#
# С помощью функции пересвязывания провести последовательность пересвязываний (не менее 15) с $p$ возрастающим в геометрической прогерссии. Визуализировать результаты пересвязывания, построить на одном графике относительные изменения коэффициента кластеризации и средней длины пути (график, аналогичный приведенному в лекции).

# %% [markdown]
# ## Лекция 4

# %% [markdown]
# __Задача #8 (4.1)__
#
# Создать собственную реализацию Лувенского (Louvain) алгоритма. Для нее выполнить визуализацию шагов алгоритма.

# %% [markdown]
# __Задача #9 (4.2)__
#
# Создать собственную реализацию алгоритма Гирвана-Ньюмена. Для нее выполнить визуализацию шагов алгоритма, показав меру посреднечества связей (цветом или толщиной) и результат каждого шага алгоритма.
#
# <center>
# <img src="./img/gn_1.png" alt="Пример визуализации алгоритма Гирвана-Ньюмена" style="width: 300px;"/><br/>
#     <em class="ex"></em> <b>Пример визуализации алгоритма Гирвана-Ньюмена</b>
# </center>

# %% [markdown]
# __Задача #10 (4.3)__
#
# Создать собственную реализацию алгоритма Гирвана-Ньюмена. Для нее выполнить визуализацию результата алгоритма с помощью дендрограммы и показать оптимальное разбиение сети с помощью критерия модулярности (показать график динамики модулряности и разбиение сети при наилучшей модулярности).
#
# <center>
# <img src="./img/gn_2.png" alt="Пример визуализации алгоритма Гирвана-Ньюмена" style="width: 500px;"/><br/>
#     <em class="ex"></em> <b>Пример визуализации алгоритма Гирвана-Ньюмена</b>
# </center>

# %% [markdown]
# __Задача #11 (4.4)__
#
# Реализовать базовый алгоритм расстановки меток с использованием случайного блуждания. Применить его для графа Карате-клуба где центры двух "группировок" (2 узла) отнесены к двум различным классам. Показать вероятность отнесения каждого узла к первому классу продублировать отнесение цветом (используя градиент).

# %% [markdown]
# __Задача #12 (4.5)__
#
# Создать собственную реализацию алгоритма распространения меток (label propagation) с реализацией "стратегии сохранения метки" (см. слайды 20-24 файла lec_06_clust_v2.pdf). С помощью алгоритма постироить (и визуализировать) не менее 5 различных (выполнить проверку с помощью соответствующего скрипта) разбиений сети Карате-клуба на различные сообщества.

# %% [markdown]
# __Задача #13 (4.6)__
#
# Написать функцию которая визулизировала сообщества в матрице инцидентности путем расположения участников сообществ близко друг к другу в матрице инцидентности. В качестве алгоритмов выявление сообществ использовать реализованные в NetworkX алгоритмы (предпочтительно - рассмотренные в рамках курса). Построить визуализацию не менее чем для 3х эмперических сетей и не менее чем для 2х алгоритмов выявления сообществ для каждой из сетей.
#
# <center>
# <img src="./img/cv_1.png" alt="Пример визуализации" style="width: 500px;"/><br/>
#     <em class="ex"></em> <b>Пример визуализации</b>
# </center>

# %% [markdown]
# ## Лекция 5

# %% [markdown]
# __Задача #14 (5.1)__
#
# Реализовать компьютерную симуляцию модели SIR:
#
# * Логика модели:
#     * каждый узел находится в одном из двух состояний $\{ S, I, R\}$
#     * на 0-м шаге $c$ узлов устанавливаются в состояние $I$ (остальные - в $S$)
#     * На каждом шаге каждый из инфецированных узлов с вероятностю $\beta$ заражает каждый из связанных с ним уязвимых узлов
#     * Каждый инфецированный узел остается инфецированным $\tau_\gamma =1/\gamma$ временных шагов, после чего переходит в состояние $R$ и не может быть вновь инфецированным. Кроме того узлы в состоянии $R$ не распространяют инфекцию.
#
# Сравнить симуляции динамики заражения узлов (в виде графиков динамики уязвимых, зраженных и резистентных узлов) сети модели для социальных сетей (не менее 3х) с несколькими тысячами узлов при 20% узлов обладают иммунитетом (т.е. изначально находятся в состоянии $R$) (например, в результате вакцинации). Рассматривается два варианта:
# * узлы обладающие иммунитетом выбираются случайно (люди вакцинируются произвольно)
# * иммунитет устанавливается у узлов с наибольшей степенью (вакцинируются наиболее контактные люди)

# %% [markdown]
# __Задача #15 (5.2)__
#
# Реализовать компьютерную симуляцию модели SIR:
#
# * Логика модели:
#     * каждый узел находится в одном из двух состояний $\{ S, I, R\}$
#     * на 0-м шаге $c$ узлов устанавливаются в состояние $I$ (остальные - в $S$)
#     * На каждом шаге каждый из инфецированных узлов с вероятностю $\beta$ заражает каждый из связанных с ним уязвимых узлов
#     * Каждый инфецированный узел остается инфецированным $\tau_\gamma =1/\gamma$ временных шагов, после чего переходит в состояние $R$ и не может быть вновь инфецированным. Кроме того узлы в состоянии $R$ не распространяют инфекцию.
#
# * Модификация модели: 10% узлов с максимальной степенью центральности изолируются т.е. имеют $\beta'=\beta/2$
#
# Сравнить симуляции динамики заражения узлов (в виде графиков динамики уязвимых, зраженных и резистентных узлов) сети модели для социальных сетей (не менее 3х) с несколькими тысячами узлов в 5 вариантах (все 5 вариантов на одном графике):
# * бзовая модель
# * модифицированная модель (степень центральности - по степени)
# * модифицированная модель (степень центральности - по близости)
# * модифицированная модель (степень центральности - по посредничеству)
# * модифицированная модель (степень центральности - по собственному значению)
#
# Интерпретировать полученный результат.

# %% [markdown]
# __Задача #16 (5.3)__
#
# Реализовать компьютерную симуляцию модели SIR:
#
# * Логика модели:
#     * каждый узел находится в одном из двух состояний $\{ S, I, R\}$
#     * на 0-м шаге $c$ узлов устанавливаются в состояние $I$ (остальные - в $S$)
#     * На каждом шаге каждый из инфецированных узлов с вероятностю $\beta$ заражает каждый из связанных с ним уязвимых узлов
#     * Каждый инфецированный узел остается инфецированным $\tau_\gamma =1/\gamma$ временных шагов, после чего переходит в состояние $R$ и не может быть вновь инфецированным. Кроме того узлы в состоянии $R$ не распространяют инфекцию.
#
# Реализовать функцию построения случайного геометрического графа (см: https://en.wikipedia.org/wiki/Random_geometric_graph ).
#
# * Построить СГГ для 225 точек со случайными координатами на прямоугольнике с углами: (0,0), (1,1) ($r$ выбираем чтообы количество средняя степень узла была равна 15)
#
# Провести симуляцию SIR для построенной сети и взуализировать каждый шаг модели. Уязвимые и зараженные узлы отражаются цветом. Положения узлов от картинки к картинке не изменяется и соответствует исходному расположению узлов при построении случайного геометрического графа.

# %% [markdown]
# ## Лекция 6

# %% [markdown]
# __Задача #17 (6.1)__
#
# Самостоятельно реализовать функцию определения центральности по близости (можно использовать функции, определяющие длину пути между узлами). Сравнить реализации собственной и встроенной в NetworkX функции. Визуализировать цветом и рзамером центроальность по близости для 3х эмпирических сетей.

# %% [markdown]
# __Задача #18 (6.2)__
#
# Самостоятельно реализовать функцию определения центральности по посреднечеству (можно использовать функции, определяющие длину пути между узлами). Сравнить реализации собственной и встроенной в NetworkX функции. Визуализировать цветом и рзамером центроальность по посреднечеству для 3х эмпирических сетей.

# %% [markdown]
# __Задача #19(6.3)__
#
# Релизовать функцию построения u,v цветка. Функция принимает один целочисленный параметр n - количество шагов построения.
#
# <center>
# <img src="./img/1_2_fl.png" alt="1,2 цветок" style="width: 200px;"/><br/>
#     <em class="ex"></em> <b>1,2 цветок</b>
# </center>
#
#
# <center>
# <img src="./img/2_2_fl.png" alt="2,2 цветок" style="width: 200px;"/><br/>
#     <em class="ex"></em> <b>2,2 цветок</b>
# </center>
#
# Для 4х различных цветков (с n>2) визуализировать цветом и рзамером центроальность: по степени, по близости, по посредничеству, по собственному вектору.

# %% [markdown]
# __Задача #20 (6.4)__
#
# Реализовать алгоритм PageRank на основе подхода слуйчайного блуждания.
#
# _из лекции:_
#
# Описание итерационного процесса блуждания:
# * $\pmb{x}(t) = M^T\pmb{x}(t-1)$
# * при $t \rightarrow \infty$ должны прийти к стационарному решению: $$\pmb{x} = M^T\pmb{x}$$
#
# <center>
# <img src="./img/l06_net1_v1.png" alt="Пример графа для обхода" style="width: 200px;"/><br/>
#     <em class="ex"></em> <b>Пример графа для обхода</b>
# </center>
#
# $$M^T = \begin{pmatrix}
# 1/3& 1/2& 0& 0\\
# 0& 0& 1/20& 1\\
# 1/3& 0& 0& 0\\
# 1/3& 1/2& 1/2& 0
# \end{pmatrix}$$
#
# 0. $\pmb{x}^T(0)=(1, 0, 0, 0)$
# 1. $\pmb{x}^T(1)=(1/3, 0, 1/3, 1/3)$
# 2. $\pmb{x}^T(2)=(0.11, 0.50, 0.11, 0.28)$
#
# ...
#
# 10. $\pmb{x}^T(10)=(0.26, 0.35, 0.09, 0.30)$
# 11. $\pmb{x}^T(11)=(0.26, 0.35, 0.09, 0.30)=\pmb{x}(10)$
#
#
# _условие остановки может быть более мягким и настраиваемым_.
#
# _в алгоритме PageRank_:
#
# Для реализации данного подхода перобразуем стохастическую матрицу $M$ следующим образом: с вероятностью $1-\alpha$ случайно перемещаемся на любую из страниц cети (здесь $E$ - eдиничная матрица, размера $N*N$):
#
# $$G = \alpha M + (1-\alpha)\frac{1}{N}E$$
#
# _Проверить на одном из графов (не менее 30 и не более 500 узлов) и сравнить с результатом PageRank из networkX._

# %% [markdown]
# __Задача #21 (6.5)__
#
# Определить, как растет средняя длина пути в сети по мере удаления из сети узлов с наивысшей центральностью. Построить график зависимости средней длины пути от количества удаленных узлов. Проверять сеть на связность - рассчитывать значения средней длины пути только для связных сетей. Построить в одной системе координат 4 графика роста средней длины пути по мере удаления наиболее центральных узлов в одной и тойже эмпирической сети (размер сети не менее 100 узлов) в 4х видах центральности: центральность по степени, центральность по близости, центральность по посредничеству и центральность по собственному вектору.
#
# Построить аналогичные 4 графика для случая, когда значения центральности пересчитываются заново после каждого шага удаления узла.
